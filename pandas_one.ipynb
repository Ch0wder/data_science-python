# %%
import pandas as pd

# %% [markdown]
# #lets see how to Import data from CSV, API(JSON), SQL Database... etc and hold the data in a dataframe object

# %%
df_movies = pd.read_csv('IMDb movies.csv', index_col= 'imdb_title_id')
df_movies
# Out:
#                                                            title  \
# imdb_title_id
# tt0000574                            The Story of the Kelly Gang
# tt0001892                                         Den sorte drøm
# tt0002101                                              Cleopatra
# tt0002130                                              L'Inferno
# tt0002199      From the Manger to the Cross; or, Jesus of Naz...
# ...                                                          ...
# tt9903716                                                 Jessie
# tt9905412                                                  Ottam
# tt9905462                                              Pengalila
# tt9911774                              Padmavyuhathile Abhimanyu
# tt9914286                                      Sokagin Çocuklari
#
#                                                   original_title  year  \
# imdb_title_id
# tt0000574                            The Story of the Kelly Gang  1906
# ...

# %%
df_movies.head(5)
# Out:
#                                                            title  \
# imdb_title_id
# tt0000574                            The Story of the Kelly Gang
# tt0001892                                         Den sorte drøm
# tt0002101                                              Cleopatra
# tt0002130                                              L'Inferno
# tt0002199      From the Manger to the Cross; or, Jesus of Naz...
#
#                                                   original_title  year  \
# imdb_title_id
# tt0000574                            The Story of the Kelly Gang  1906
# tt0001892                                         Den sorte drøm  1911
# tt0002101                                              Cleopatra  1912
# tt0002130                                              L'Inferno  1911
# tt0002199      From the Manger to the Cross; or, Jesus of Naz...  1912
#
#               date_published                      genre  duration  \
# imdb_title_id
# ...

# %%
df_movies.loc[4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-2212fd930ec8> in <module>
# ----> 1 df_movies.loc[4]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1961
#    1962         # fall thru to straight lookup
# -> 1963         self._validate_key(key, axis)
#    1964         return self._get_label(key, axis=axis)
#    1965
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1828
#    1829         if not is_list_like_indexer(key):
# ...

# %%
df_movies = pd.read_csv('IMDb movies.csv', index_col= 'imdb_title_id' )

# %%
df_movies.head(2)

# %%
df_posts=pd.read_json('https://jsonplaceholder.typicode.com/posts' )

# %%
df_posts.head(2)

# %%
df_posts['id'].count() == len(set(df_posts['id']))

# %%
df_posts['id'].count()

# %%
len(set(df_posts['id']))

# %%
df_posts['id'].count()

# %%
df_posts.set_index('id', inplace=True)

# %%
df_posts.head()

# %%
df_movies.head()

# %% [markdown]
# ## Pre-requisites of Exploratory Data Analysis i.e Descriptive Stats
#
# * run df.info() to check column/row freqursncies of null/non-null values.
# * If more than half the values are None/N/A/Null values, then we could drop the column.
# * If the null values are few, we can replace them with mean/median/mode
# * Deal with duplcates
#
# ## Perform descriptive Statistics
#
# * Run describe() method  on your data frame. This will show the frequency/mean/min/max/standard deviation/variance of continuous values (numbers only)
#
# * Check the relationship between continuous variables i.e one column and another.
#
# ## Data Visualization

# %%
df_movies.info()

# %% [markdown]
# __Country seems to have 39 null values. How do we deal with this? __

# %% [markdown]
# if all null values are to be replaced by a measure of central tendency, we'd take the mode.

# %%
movies_df.columns

# %%
df_movies.columns

# %%
df_movies.rename(columns={
    'country':'nation'},inplace = True)

# %%
df_movies.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66277ef22275> in <module>
# ----> 1 df_movies.head(2)
#
# NameError: name 'df_movies' is not defined

# %%
import psychopg2 as pg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-cf0760f42776> in <module>
# ----> 1 import psychopg2 as pg
#
# ModuleNotFoundError: No module named 'psychopg2'

# %%
con = ps.connect("host=localhost user=postgres password=123456 dbname=sales_data")

# %%
df_movies_one = pd.read_csv('data/imdb_data_1000.csv', index_col='Rank')

# %%
df_movies_one.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df_movies_one['Rank'].count()== len(set(df_movies_one['Rank']))
# Out:
# True

# %%
df_movies_one.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df_movies_one.rename(columns = { 'Runtime (Minutes)':'Runtime_Minutes',
                                'Revenue (Millions)': 'Revenue_Milllions'}, inplace = True)

# %%
df_movies_one.columns = [c.lower() for c in df_movies_one]

# %%
df_movies_one.columns
# Out:
# Index(['title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime_minutes', 'rating', 'votes', 'revenue_milllions', 'metascore'],
#       dtype='object')

# %%
df_movies_one.shape
# Out:
# (1000, 11)

# %%
df_movies_one.drop_duplicates(keep='first', inplace = True)

# %% [markdown]
#  ### Create a temporary data frame, create duplicate values using append method
